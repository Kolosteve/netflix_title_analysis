# %% [markdown]
# Try-Except Block: how correct errors in python

# %%
first_number = float(input("Enter first number: "))

second_number = float(input("Enter second number: "))

result = first_number/second_number

print(result)
# Out:
# Enter first number:  65
# Enter second number:  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 first_number = float(input("Enter first number: "))
#       3 second_number = float(input("Enter second number: "))
# ----> 5 result = first_number/second_number
#       7 print(result)
#
# ZeroDivisionError: float division by zero

# %%
try:
    first_number = float(input("Enter first number: "))

    second_number = float(input("Enter second number: "))

    result = first_number/second_number
except ZeroDivisionError:
     print("you can't divide by zero")
except ValueError:
    print("You didn't enter a valid number")
else:
    print(result)
# Out:
# Enter first number:  14
# Enter second number:  0
# you can't divide by zero

# %%
try:
    first_number = float(input("Enter first number: "))

    second_number = float(input("Enter second number: "))

    result = first_number/second_number
except:
    print("Your input is not valid")
else:
    print(result)
# Out:
# Enter first number:  23
# Enter second number:  0
# Your input is not valid

# %% [markdown]
# # Modules in Python
#
# Modules is like library that contain different functions

# %%
#Math Module: Inbuilt module that contains different mathematical functions
#Before you can use module function you need to first import them.

import math

# %%
math.sqrt(16) #To square
# Out:
# 4.0

# %%
#To round up the result from float

math.ceil(9.8)
# Out:
# 10

# %%
#To round down

math.floor(9.8)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
#Random Module

import random

# %%
random.random() #gives you a random value between 0.0 and 1.0
# Out:
# 0.34767368855813685

# %%
random.randint(1, 10) #a random integer between 1 to 10
# Out:
# 9

# %%
random.uniform(10, 20) #a random float between 10 to 20
# Out:
# 18.60511791903589

# %%
#To choice a random item from the list

numbers = [1, 2, 3, 4, 5]

# %%
random.choice(numbers)
# Out:
# 4

# %%
#dattime Module

import datetime

# %%
datetime.datetime.now() #To get todays date and time
# Out:
# datetime.datetime(2026, 1, 22, 16, 39, 7, 215524)

# %%
datetime.date.today() #Another way to get todays date
# Out:
# datetime.date(2026, 1, 22)

# %%
datetime.date.today() - datetime.timedelta(days=1) #To find yesterday date
# Out:
# datetime.date(2026, 1, 21)
